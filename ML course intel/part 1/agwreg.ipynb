# %%
import pandas as pd
import numpy as np

# %%
data=[132,123,321,159,951]
datapd=pd.Series(data,name='pirveli')
datapd.index=pd.date_range('20230228',periods=5)
#datapd[1:3]=np.nan
#datapd.fillna(0,inplace=True)
datapd
# Out:
# 2023-02-28    132
# 2023-03-01    123
# 2023-03-02    321
# 2023-03-03    159
# 2023-03-04    951
# Freq: D, Name: pirveli, dtype: int64

# %%
otherdata=['6516','15984','68510','19851','654651']
datapd2=pd.Series(otherdata,name='meore')
joineddata=list(zip(data,otherdata))
df=pd.DataFrame(joineddata)
df.index=pd.date_range('20230228',periods=5)
df.columns=['pirveli','meore']
df['pirveli']
# Out:
# 2023-02-28    132
# 2023-03-01    123
# 2023-03-02    321
# 2023-03-03    159
# 2023-03-04    951
# Freq: D, Name: pirveli, dtype: int64

# %%
df=pd.read_csv('Iris_Data.csv')
df['sepal_area']=df.sepal_length*df.sepal_width
df['abbrev']=df.species.apply(lambda x: x.replace('Iris-',''))
#df
smalldf=pd.concat([df.iloc[:2],df.iloc[-2:]])
#smalldf

#print(df.groupby('species').size())

#df.mean()
#df.median()
#df.mode()
#df.std()
#df.var()
#df.sem()
#df.quantile()
#df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_area
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667   17.806533
# std        0.828066     0.433594      1.764420     0.763161    3.368693
# min        4.300000     2.000000      1.000000     0.100000   10.000000
# 25%        5.100000     2.800000      1.600000     0.300000   15.645000
# 50%        5.800000     3.000000      4.350000     1.300000   17.660000
# 75%        6.400000     3.300000      5.100000     1.800000   20.325000
# max        7.900000     4.400000      6.900000     2.500000   30.020000

# %%
sample=df.sample(n=5,replace=False,random_state=42)
sample
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 73            6.1          2.8           4.7          1.2  Iris-versicolor
# 18            5.7          3.8           1.7          0.3      Iris-setosa
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# 78            6.0          2.9           4.5          1.5  Iris-versicolor
# 76            6.8          2.8           4.8          1.4  Iris-versicolor
#
#      sepal_area      abbrev
# 73        17.08  versicolor
# 18        21.66      setosa
# 118       20.02   virginica
# 78        17.40  versicolor
# 76        19.04  versicolor

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_area     abbrev
# 0         17.85     setosa
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(df.sepal_length,df.sepal_width,marker='o',ls='')

# %%
plt.plot(df.sepal_width,df.sepal_length,marker='o',ls='',label='petal')
plt.plot(df.sepal_length,df.sepal_width,marker='o',ls='',label='sepal')

# %%
plt.hist(df.sepal_length,bins=25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <BarContainer object of 25 artists>)

# %%
fig , ax = plt.subplots()

ax.barh(np.arange(10),df.sepal_width.iloc[:10])

ax.set_yticks(np.arange(0.4,10.4,1.0))
ax.set_ytickslabel(np.arange(1,11))
ax.set(xlabel='xlabel',ylabel='ylabel',title='title')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\my projects\test\agwreg.ipynb Cell 10 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/my%20projects/test/agwreg.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> ax.barh(np.arange(10),df.sepal_width.iloc[:10])
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/my%20projects/test/agwreg.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> ax.set_yticks(np.arange(0.4,10.4,1.0))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/my%20projects/test/agwreg.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> ax.set_ytickslabel(np.arange(1,11))
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/my%20projects/test/agwreg.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> ax.set(xlabel='xlabel',ylabel='ylabel',title='title')
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_ytickslabel'

# %%
df.groupby('species').mean().plot(color=['red','blue','black','green'],fontsize=10, figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='species'>

# %%
import seaborn as sns

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df,height=10,hue='species')

# %%
sns.pairplot(df,hue='species',height=20,markers='o',plot_kws={"s": 300})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\my projects\test\agwreg.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/my%20projects/test/agwreg.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> sns.pairplot(df,hue='species',height=20,markers='o',plot_kws={"s": 300,'f':20})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...
